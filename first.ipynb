# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

import pickle


#read dataset
dataset = pd.read_csv('diabetes.csv')
dataset.tail(15)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 753            0      181             88             44      510  43.3
# 754            8      154             78             32        0  32.4
# 755            1      128             88             39      110  36.5
# 756            7      137             90             41        0  32.0
# 757            0      123             72              0        0  36.3
# 758            1      106             76              0        0  37.5
# 759            6      190             92              0        0  35.5
# 760            2       88             58             26       16  28.4
# 761            9      170             74             31        0  44.0
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 753                     0.222   26        1
# 754                     0.443   45        1
# 755                     1.057   37        1
# 756                     0.391   39        0
# 757                     0.258   52        1
# 758                     0.197   26        0
# 759                     0.278   66        1
# 760                     0.766   22        0
# 761                     0.403   43        1
# 762                     0.142   33        0
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
(dataset == 0).sum()

# %%
mean_bmi = dataset['BMI'].mean(skipna=True)
dataset.loc[dataset.BMI == 0, 'BMI'] = mean_bmi



mean_Glucose = dataset['Glucose'].mean(skipna=True)
dataset.loc[dataset.Glucose == 0, 'Glucose'] = mean_Glucose

mean_BloodPressure = dataset['BloodPressure'].mean(skipna=True)
dataset.loc[dataset.BloodPressure == 0, 'BloodPressure'] = mean_BloodPressure



# mean_Insulin = dataset['Insulin'].mean(skipna=True)
# dataset.loc[dataset.Insulin == 0, 'Insulin'] = mean_Insulin

# %%
(dataset == 0).sum()

# %%
#make input(X) and output(Y)
X = dataset[['Glucose','BloodPressure','BMI','DiabetesPedigreeFunction']]
Y = dataset.iloc[:,  -1]

# %%
X.head(15)
X.tail(15)
# Out:
#      Glucose  BloodPressure   BMI  DiabetesPedigreeFunction
# 753    181.0           88.0  43.3                     0.222
# 754    154.0           78.0  32.4                     0.443
# 755    128.0           88.0  36.5                     1.057
# 756    137.0           90.0  32.0                     0.391
# 757    123.0           72.0  36.3                     0.258
# 758    106.0           76.0  37.5                     0.197
# 759    190.0           92.0  35.5                     0.278
# 760     88.0           58.0  28.4                     0.766
# 761    170.0           74.0  44.0                     0.403
# 762     89.0           62.0  22.5                     0.142
# 763    101.0           76.0  32.9                     0.171
# 764    122.0           70.0  36.8                     0.340
# 765    121.0           72.0  26.2                     0.245
# 766    126.0           60.0  30.1                     0.349
# 767     93.0           70.0  30.4                     0.315

# %%
#find missing values
dataset.isnull().sum(axis=0)
dataset.head(15)

# %%
from sklearn.preprocessing import MinMaxScaler
mmScaler=MinMaxScaler(feature_range=(0,1))
rescaleX=mmScaler.fit_transform(X)
rescaleX

# %%
X[:].mean()
X[:].std()
from sklearn.preprocessing import StandardScaler
sScaler=StandardScaler()
reScaleX=sScaler.fit_transform(X)
reScaleX
reScaleX[:,0].mean()
reScaleX[:,0].std()

# %%
from sklearn.preprocessing import Normalizer
norm=Normalizer()
norm.fit_transform(X)

# %%
from sklearn.preprocessing import Binarizer
bina=Binarizer(threshold=5).fit(X)
bina.fit_transform(X)

# %%
X.head(15)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(dataset.Outcome,dataset.BloodPressure)
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(dataset.Outcome,dataset.Glucose)
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(dataset.Outcome,dataset.DiabetesPedigreeFunction	)
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(dataset.Outcome,dataset.BMI)
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,Y,train_size=0.8)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, y_train)

# %%
y_predicted = model.predict(X_test)

# %%
model.predict_proba(X_test)

# %%
model.score(X_test,y_test)

# %%
print(model.predict([[190,92,35.5,0.278]]))
# Out:
# [1]

# %%
pickle.dump(model, open('web.pkl','wb'))

# %%
web = pickle.load(open('web.pkl','rb'))

# %%
#Correlation with output vdkiable

# df = dataset.select_dtypes(exclude=[object])
# correlation = df.corr()
# round(correlation, 3)

# cor_target = abs(correlation["BMI"])

# #SeLecting highly correlated features
# relevant_features = cor_target[cor_target>=0.9]

# dataset = dataset[relevant_features. index]
# print(dataset.shape)
# dataset.columns

# %%
# # checking mutual correlation of columns and remove those with correlation greater than 6.9
# df_mutual = dataset.select_dtypes(exclude=[object])
# corr = df_mutual.corr()
# columns = np.full((corr.shape[0],), True, dtype=bool)
# for i in range(corr.shape[0]):
#     for j in range(i+1, corr.shape[0]):
#         if corr.iloc(i,j) >= 0.9:
#             if columns[j]:
#                 columns[j] = False
# selected_columns = df_mutual.columns[columns]
# dataset = dataset[selected_columns]
# print(dataset.shape)

# print(corr)

# %%
# dataset=dataset.drop(dataset.std()[dataset.std()<=0].index.values,axis=1)
# dataset.shape
